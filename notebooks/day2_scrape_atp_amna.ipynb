# %%
import pandas as pd
import requests
from selenium import webdriver

# %%
# !pip install selenium-stealth 
# !pip install selenium 
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: selenium-stealth in c:\users\amna adnan\anaconda3\lib\site-packages (1.0.6)
# Requirement already satisfied: selenium in c:\users\amna adnan\anaconda3\lib\site-packages (from selenium-stealth) (4.4.3)
# Requirement already satisfied: trio~=0.17 in c:\users\amna adnan\anaconda3\lib\site-packages (from selenium->selenium-stealth) (0.21.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\amna adnan\anaconda3\lib\site-packages (from selenium->selenium-stealth) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\amna adnan\anaconda3\lib\site-packages (from selenium->selenium-stealth) (2021.10.8)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\amna adnan\anaconda3\lib\site-packages (from selenium->selenium-stealth) (1.26.9)
# Requirement already satisfied: async-generator>=1.9 in c:\users\amna adnan\anaconda3\lib\site-packages (from trio~=0.17->selenium->selenium-stealth) (1.10)
# Requirement already satisfied: sniffio in c:\users\amna adnan\anaconda3\lib\site-packages (from trio~=0.17->selenium->selenium-stealth) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\amna adnan\anaconda3\lib\site-packages (from trio~=0.17->selenium->selenium-stealth) (21.4.0)
# Requirement already satisfied: outcome in c:\users\amna adnan\anaconda3\lib\site-packages (from trio~=0.17->selenium->selenium-stealth) (1.2.0)
# Requirement already satisfied: idna in c:\users\amna adnan\anaconda3\lib\site-packages (from trio~=0.17->selenium->selenium-stealth) (3.3)
# Requirement already satisfied: cffi>=1.14 in c:\users\amna adnan\anaconda3\lib\site-packages (from trio~=0.17->selenium->selenium-stealth) (1.15.0)
# Requirement already satisfied: sortedcontainers in c:\users\amna adnan\anaconda3\lib\site-packages (from trio~=0.17->selenium->selenium-stealth) (2.4.0)
# Requirement already satisfied: pycparser in c:\users\amna adnan\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium->selenium-stealth) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\amna adnan\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium->selenium-stealth) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\amna adnan\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium->selenium-stealth) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\amna adnan\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->selenium-stealth) (0.13.0)
# Requirement already satisfied: selenium in c:\users\amna adnan\anaconda3\lib\site-packages (4.4.3)
# Requirement already satisfied: trio~=0.17 in c:\users\amna adnan\anaconda3\lib\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\amna adnan\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\amna adnan\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\amna adnan\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\amna adnan\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sniffio in c:\users\amna adnan\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\amna adnan\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\amna adnan\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\users\amna adnan\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sortedcontainers in c:\users\amna adnan\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in c:\users\amna adnan\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\amna adnan\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\amna adnan\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\amna adnan\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\amna adnan\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)
# Requirement already satisfied: webdriver-manager in c:\users\amna adnan\anaconda3\lib\site-packages (3.8.3)
# Requirement already satisfied: python-dotenv in c:\users\amna adnan\anaconda3\lib\site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: tqdm in c:\users\amna adnan\anaconda3\lib\site-packages (from webdriver-manager) (4.64.0)
# Requirement already satisfied: requests in c:\users\amna adnan\anaconda3\lib\site-packages (from webdriver-manager) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amna adnan\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amna adnan\anaconda3\lib\site-packages (from requests->webdriver-manager) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\amna adnan\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\amna adnan\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: colorama in c:\users\amna adnan\anaconda3\lib\site-packages (from tqdm->webdriver-manager) (0.4.4)

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

from selenium import webdriver
from selenium_stealth import stealth

options = webdriver.ChromeOptions()
options.add_argument("start-maximized")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
driver = webdriver.Chrome(options=options, executable_path=ChromeDriverManager().install())

stealth(driver,
        languages=["en-US", "en"],
        vendor="Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Inc.",
        renderer="Intel Iris OpenGL Engine",
        fix_hairline=True,
        )
# Out:
# C:\Users\Amna Adnan\AppData\Local\Temp\ipykernel_10048\3634333721.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options, executable_path=ChromeDriverManager().install())

# %%
driver.get("https://www.atptour.com/-/ajax/HawkEyeStats/Opponents/D643")

# %%
import json
json_player = json.loads(driver.find_element(by="xpath", value='/html/body/pre').text)

# %%
lst=[]
for x in range(100):
    lst.append(json_player[x]['OpponentId'])
    
player_id_lst=lst[3:100]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [168], in <cell line: 2>()
#       1 lst=[]
#       2 for x in range(100):
# ----> 3     lst.append(json_player[x]['OpponentId'])
#       5 player_id_lst=lst[3:100]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
len(player_id_lst)
# Out:
# 97

# %% [markdown]
# ### HEIGHTS OF 100 OPPONENTS ###

# %%
names = ['Novak Djokovic','Daniil Medvedev','Alexander Zverev','Stefanos Tsitsipas','Andrey Rublev','Rafael Nadal',
         'Matteo Berrettini','Casper Ruud','Hubert Hurkacz','Felix Auger-Aliassime','Jannik Sinner','Cameron Norrie',
        'Diego Schwartzman','Denis Shapovalov','Dominic Thiem','Roger Federer','Aslan Karatsev','Cristian Garin',
        'Roberto Bautista Agut','Pablo Carreno Busta','Gael Monfils','Nikoloz Basilashvili','Taylor Fritz','John Isner',
        'Daniel Evans','Reilly Opelka','Lorenzo Sonego','Grigor Dimitrov','Karen Khachanov','Marin Cillic','Lloyd Harris',
        'Carlos Alcaraz','Dusan Lajovic','Alex De Minaur','Ugo Humbert','Alexander Bublik','Fabio Fognini','Frances Tiafoe',
        'David Goffin','Marton Fucsovics','Sebastian Korda','Filip Krajinovic','Tommy Paul','Federico Delbonis','Albert Ramos-Vinolas',
        'Ilya Ivashka','Benoit Paire','Kei Nishikori','James Duckworth','Alejandro Davidovich Fokina','Jan-Lennard Struff',
        'Laslo Djere','Soonwoo Kwon','Dominik Koepfer','Mackenzie McDonald','Jenson Brooksby','Botic Van De Zandschulp',
        'Arthur Rinderknech','Lorenzo Musetti','Pedro Martinez','Alexei Popyrin','Brandon Nakashima','Gianluca Mager',
        'Benjamin Bonzi','Tallon Griekspoor','Marcos Giron','Hugo Gaston','Miomir Kecmanovic','Federico Coria','Milos Raonic',
        'Roberto Carballes Baena','Adrian Mannarino','John Millman','Borna Coric','Guido Pella','Facunda Bagnis','Jordan Thompson',
        'Stefano Travaglia','Kevin Anderson','Yoshihito Nishioka','Stan Wawrinka','Jiri Vesely','Jaume Munar','Steve Johnson',
        'Peter Gojowczyk','Richard Gasquet','Pablo Andujar','Corentin Moutet','Juan Manuel Cerundolo','Nick Kyrgios',
        'Mikael Ymer','Emil Ruusuvuori','Tennys Sandgren','Thiago Monteiro','Pablo Cuevas','Marco Cecchinato','Henri Laaksonen',
        'Daniel Altmaier','Carlos Taberner','Andreas Seppi']

# %%
height = [188,198,198,193,188,185,196,183,196,193,188,188,170,185,185,185,185,185,183,188,193,185,196,208,175,211,191,191,198,
            198,193,185,183,183,188,196,178,188,180,188,196,185,185,193,188,193,196,178,183,183,193,188,180,180,178,193,191,
            196,185,185,196,185,188,183,188,180,173,183,180,196,183,180,183,188,183,183,183,185,203,170,183,198,183,188,188,
            183,180,175,183,193,183,188,188,183,180,185,185,188,183,191]

# %%
res = dict(zip(names, height))

# %% [markdown]
# ### API's for DJOKOVIC OPPONENTS WITH ALL STATISTICS ###

# %% [markdown]
# ### DEUCE COURT OF ALL OPPONENTS ###

# %%
player_lst=[]
for id in player_id_lst:
    driver.get(f'https://www.atptour.com/-/ajax/hawkeyestats/serve/2020/0/D643/deucecourt/1/all/{id}/all')
    json_player=json.loads(driver.find_element(by="xpath", value='/html/body/pre').text)
    player_lst.append(json_player)

# %% [markdown]
# ### ADCOURT OF OPPONENTS ###

# %%
player_ad_lst=[]
for id in player_id_lst:
    driver.get(f'https://www.atptour.com/-/ajax/hawkeyestats/serve/2020/0/D643/adcourt/1/all/{id}/all')
    json_ad_player=json.loads(driver.find_element(by="xpath", value='/html/body/pre').text)
    player_ad_lst.append(json_ad_player)

# %%
filtered_ad_lst=['None' if v is None else v for v in player_ad_lst]
len(filtered_ad_lst)
filtered_ad_lst
# Out:
# ['None',
#  'None',
#  {'T': {'AdCourt': {'FirstServesAttempted': 28,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 28,
#     'TotalServesMade': 26,
#     'Summary': {'ServesAttempted': 12,
#      'ServesMade': 12,
#      'ServesWon': 9,
#      'ServesMadePercentage': '46.2%',
#      'ServesWonPercentage': '75.0%',
#      'Aces': 2,
#      'Unreturned': 3,
#      'Returned': 7,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 4,
#      'ServesMade': 4,
#      'ServesWon': 3,
#      'ServesMadePercentage': '33.3%',
#      'ServesWonPercentage': '75.0%',
#      'Aces': 0,
#      'Unreturned': 2,
#      'Returned': 2,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '16.7%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 2,
#      'AverageSpeed': 120.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 3,
#      'ServesMade': 3,
#      'ServesWon': 2,
#      'ServesMadePercentage': '25.0%',
#      'ServesWonPercentage': '66.7%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 2,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 3,
#      'ServesMade': 3,
#      'ServesWon': 2,
#      'ServesMadePercentage': '25.0%',
#      'ServesWonPercentage': '66.7%',
#      'Aces': 2,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 123.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Mid': {'AdCourt': {'FirstServesAttempted': 28,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 28,
#     'TotalServesMade': 26,
#     'Summary': {'ServesAttempted': 2,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '3.8%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 123.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 1,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '100.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 123.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Wide': {'AdCourt': {'FirstServesAttempted': 28,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 28,
#     'TotalServesMade': 26,
#     'Summary': {'ServesAttempted': 14,
#      'ServesMade': 13,
#      'ServesWon': 12,
#      'ServesMadePercentage': '50.0%',
#      'ServesWonPercentage': '92.3%',
#      'Aces': 1,
#      'Unreturned': 6,
#      'Returned': 6,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '7.7%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 125.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '15.4%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 1,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 5,
#      'ServesMade': 4,
#      'ServesWon': 3,
#      'ServesMadePercentage': '30.8%',
#      'ServesWonPercentage': '75.0%',
#      'Aces': 0,
#      'Unreturned': 2,
#      'Returned': 2,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 5,
#      'ServesMade': 5,
#      'ServesWon': 5,
#      'ServesMadePercentage': '38.5%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 1,
#      'Unreturned': 3,
#      'Returned': 1,
#      'AverageSpeed': 125.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '7.7%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'CacheTags': None},
#  'None',
#  'None',
#  'None',
#  'None',
#  {'T': {'AdCourt': {'FirstServesAttempted': 27,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 27,
#     'TotalServesMade': 27,
#     'Summary': {'ServesAttempted': 13,
#      'ServesMade': 13,
#      'ServesWon': 8,
#      'ServesMadePercentage': '48.1%',
#      'ServesWonPercentage': '61.5%',
#      'Aces': 1,
#      'Unreturned': 6,
#      'Returned': 6,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 0,
#      'ServesMadePercentage': '7.7%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 1,
#      'ServesMadePercentage': '15.4%',
#      'ServesWonPercentage': '50.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 2,
#      'AverageSpeed': 119.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '7.7%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 6,
#      'ServesMade': 6,
#      'ServesWon': 4,
#      'ServesMadePercentage': '46.2%',
#      'ServesWonPercentage': '66.7%',
#      'Aces': 1,
#      'Unreturned': 3,
#      'Returned': 2,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 3,
#      'ServesMade': 3,
#      'ServesWon': 2,
#      'ServesMadePercentage': '23.1%',
#      'ServesWonPercentage': '66.7%',
#      'Aces': 0,
#      'Unreturned': 2,
#      'Returned': 1,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Mid': {'AdCourt': {'FirstServesAttempted': 27,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 27,
#     'TotalServesMade': 27,
#     'Summary': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '3.7%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '100.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Wide': {'AdCourt': {'FirstServesAttempted': 27,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 27,
#     'TotalServesMade': 27,
#     'Summary': {'ServesAttempted': 13,
#      'ServesMade': 13,
#      'ServesWon': 10,
#      'ServesMadePercentage': '48.1%',
#      'ServesWonPercentage': '76.9%',
#      'Aces': 6,
#      'Unreturned': 2,
#      'Returned': 5,
#      'AverageSpeed': 120.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '7.7%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 86.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 7,
#      'ServesMade': 7,
#      'ServesWon': 7,
#      'ServesMadePercentage': '53.8%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 6,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 4,
#      'ServesMade': 4,
#      'ServesWon': 1,
#      'ServesMadePercentage': '30.8%',
#      'ServesWonPercentage': '25.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 3,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '7.7%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'CacheTags': None},
#  'None',
#  'None',
#  'None',
#  {'T': {'AdCourt': {'FirstServesAttempted': 16,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 16,
#     'TotalServesMade': 16,
#     'Summary': {'ServesAttempted': 7,
#      'ServesMade': 7,
#      'ServesWon': 5,
#      'ServesMadePercentage': '43.8%',
#      'ServesWonPercentage': '71.4%',
#      'Aces': 1,
#      'Unreturned': 3,
#      'Returned': 3,
#      'AverageSpeed': 116.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 0,
#      'ServesMadePercentage': '14.3%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '14.3%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 114.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '14.3%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 112.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 1,
#      'ServesMadePercentage': '28.6%',
#      'ServesWonPercentage': '50.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 1,
#      'AverageSpeed': 115.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '28.6%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 1,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 120.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Mid': {'AdCourt': {'FirstServesAttempted': 16,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 16,
#     'TotalServesMade': 16,
#     'Summary': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Wide': {'AdCourt': {'FirstServesAttempted': 16,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 16,
#     'TotalServesMade': 16,
#     'Summary': {'ServesAttempted': 9,
#      'ServesMade': 9,
#      'ServesWon': 4,
#      'ServesMadePercentage': '56.2%',
#      'ServesWonPercentage': '44.4%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 8,
#      'AverageSpeed': 119.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 0,
#      'ServesMadePercentage': '11.1%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 125.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '11.1%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 125.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '11.1%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 4,
#      'ServesMade': 4,
#      'ServesWon': 1,
#      'ServesMadePercentage': '44.4%',
#      'ServesWonPercentage': '25.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 3,
#      'AverageSpeed': 114.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 1,
#      'ServesMadePercentage': '22.2%',
#      'ServesWonPercentage': '50.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 2,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'CacheTags': None},
#  'None',
#  'None',
#  'None',
#  'None',
#  {'T': {'AdCourt': {'FirstServesAttempted': 15,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 15,
#     'TotalServesMade': 14,
#     'Summary': {'ServesAttempted': 6,
#      'ServesMade': 6,
#      'ServesWon': 6,
#      'ServesMadePercentage': '42.9%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 3,
#      'Unreturned': 1,
#      'Returned': 2,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '16.7%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 5,
#      'ServesMade': 5,
#      'ServesWon': 5,
#      'ServesMadePercentage': '83.3%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 3,
#      'Unreturned': 0,
#      'Returned': 2,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Mid': {'AdCourt': {'FirstServesAttempted': 15,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 15,
#     'TotalServesMade': 14,
#     'Summary': {'ServesAttempted': 3,
#      'ServesMade': 3,
#      'ServesWon': 2,
#      'ServesMadePercentage': '21.4%',
#      'ServesWonPercentage': '66.7%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 2,
#      'AverageSpeed': 125.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 0,
#      'ServesMadePercentage': '33.3%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 127.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '33.3%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 126.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '33.3%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Wide': {'AdCourt': {'FirstServesAttempted': 15,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 15,
#     'TotalServesMade': 14,
#     'Summary': {'ServesAttempted': 6,
#      'ServesMade': 5,
#      'ServesWon': 4,
#      'ServesMadePercentage': '35.7%',
#      'ServesWonPercentage': '80.0%',
#      'Aces': 0,
#      'Unreturned': 3,
#      'Returned': 2,
#      'AverageSpeed': 106.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '20.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 93.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 2,
#      'ServesMade': 1,
#      'ServesWon': 0,
#      'ServesMadePercentage': '20.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 90.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '40.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 2,
#      'Returned': 0,
#      'AverageSpeed': 112.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '20.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'CacheTags': None},
#  'None',
#  'None',
#  'None',
#  {'T': {'AdCourt': {'FirstServesAttempted': 21,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 21,
#     'TotalServesMade': 21,
#     'Summary': {'ServesAttempted': 10,
#      'ServesMade': 10,
#      'ServesWon': 8,
#      'ServesMadePercentage': '47.6%',
#      'ServesWonPercentage': '80.0%',
#      'Aces': 0,
#      'Unreturned': 2,
#      'Returned': 8,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '10.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '20.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 1,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 4,
#      'ServesMade': 4,
#      'ServesWon': 2,
#      'ServesMadePercentage': '40.0%',
#      'ServesWonPercentage': '50.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 4,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 3,
#      'ServesMade': 3,
#      'ServesWon': 3,
#      'ServesMadePercentage': '30.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 2,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Mid': {'AdCourt': {'FirstServesAttempted': 21,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 21,
#     'TotalServesMade': 21,
#     'Summary': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '4.8%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '100.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Wide': {'AdCourt': {'FirstServesAttempted': 21,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 21,
#     'TotalServesMade': 21,
#     'Summary': {'ServesAttempted': 10,
#      'ServesMade': 10,
#      'ServesWon': 9,
#      'ServesMadePercentage': '47.6%',
#      'ServesWonPercentage': '90.0%',
#      'Aces': 2,
#      'Unreturned': 2,
#      'Returned': 6,
#      'AverageSpeed': 125.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '20.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 2,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 3,
#      'ServesMade': 3,
#      'ServesWon': 3,
#      'ServesMadePercentage': '30.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 2,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 126.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 3,
#      'ServesMade': 3,
#      'ServesWon': 2,
#      'ServesMadePercentage': '30.0%',
#      'ServesWonPercentage': '66.7%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 2,
#      'AverageSpeed': 125.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '20.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 1,
#      'AverageSpeed': 125.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'CacheTags': None},
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  {'T': {'AdCourt': {'FirstServesAttempted': 14,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 14,
#     'TotalServesMade': 14,
#     'Summary': {'ServesAttempted': 9,
#      'ServesMade': 9,
#      'ServesWon': 7,
#      'ServesMadePercentage': '64.3%',
#      'ServesWonPercentage': '77.8%',
#      'Aces': 0,
#      'Unreturned': 4,
#      'Returned': 5,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 1,
#      'ServesMadePercentage': '22.2%',
#      'ServesWonPercentage': '50.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 1,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '11.1%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 120.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '22.2%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 2,
#      'Returned': 0,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 4,
#      'ServesMade': 4,
#      'ServesWon': 3,
#      'ServesMadePercentage': '44.4%',
#      'ServesWonPercentage': '75.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 4,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Mid': {'AdCourt': {'FirstServesAttempted': 14,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 14,
#     'TotalServesMade': 14,
#     'Summary': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '7.1%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '100.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Wide': {'AdCourt': {'FirstServesAttempted': 14,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 14,
#     'TotalServesMade': 14,
#     'Summary': {'ServesAttempted': 4,
#      'ServesMade': 4,
#      'ServesWon': 3,
#      'ServesMadePercentage': '28.6%',
#      'ServesWonPercentage': '75.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 3,
#      'AverageSpeed': 118.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '25.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 3,
#      'ServesMade': 3,
#      'ServesWon': 2,
#      'ServesMadePercentage': '75.0%',
#      'ServesWonPercentage': '66.7%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 3,
#      'AverageSpeed': 116.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'CacheTags': None},
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  {'T': {'AdCourt': {'FirstServesAttempted': 15,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 15,
#     'TotalServesMade': 15,
#     'Summary': {'ServesAttempted': 8,
#      'ServesMade': 8,
#      'ServesWon': 7,
#      'ServesMadePercentage': '53.3%',
#      'ServesWonPercentage': '87.5%',
#      'Aces': 0,
#      'Unreturned': 4,
#      'Returned': 4,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 0,
#      'ServesMadePercentage': '12.5%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 125.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '12.5%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 123.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 4,
#      'ServesMade': 4,
#      'ServesWon': 4,
#      'ServesMadePercentage': '50.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 2,
#      'Returned': 2,
#      'AverageSpeed': 120.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '25.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 1,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Mid': {'AdCourt': {'FirstServesAttempted': 15,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 15,
#     'TotalServesMade': 15,
#     'Summary': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '6.7%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '100.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Wide': {'AdCourt': {'FirstServesAttempted': 15,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 15,
#     'TotalServesMade': 15,
#     'Summary': {'ServesAttempted': 6,
#      'ServesMade': 6,
#      'ServesWon': 4,
#      'ServesMadePercentage': '40.0%',
#      'ServesWonPercentage': '66.7%',
#      'Aces': 0,
#      'Unreturned': 3,
#      'Returned': 3,
#      'AverageSpeed': 113.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 0,
#      'ServesMadePercentage': '16.7%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 93.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '16.7%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 125.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 0,
#      'ServesMadePercentage': '16.7%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 86.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '16.7%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 125.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '33.3%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 1,
#      'AverageSpeed': 125.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'CacheTags': None},
#  'None',
#  'None',
#  {'T': {'AdCourt': {'FirstServesAttempted': 13,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 13,
#     'TotalServesMade': 13,
#     'Summary': {'ServesAttempted': 5,
#      'ServesMade': 5,
#      'ServesWon': 5,
#      'ServesMadePercentage': '38.5%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 2,
#      'Returned': 3,
#      'AverageSpeed': 118.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '20.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 111.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '20.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '20.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '40.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 1,
#      'AverageSpeed': 118.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Mid': {'AdCourt': {'FirstServesAttempted': 13,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 13,
#     'TotalServesMade': 13,
#     'Summary': {'ServesAttempted': 3,
#      'ServesMade': 3,
#      'ServesWon': 3,
#      'ServesMadePercentage': '23.1%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 2,
#      'Returned': 1,
#      'AverageSpeed': 123.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '33.3%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '33.3%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '33.3%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 123.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Wide': {'AdCourt': {'FirstServesAttempted': 13,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 13,
#     'TotalServesMade': 13,
#     'Summary': {'ServesAttempted': 5,
#      'ServesMade': 5,
#      'ServesWon': 4,
#      'ServesMadePercentage': '38.5%',
#      'ServesWonPercentage': '80.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 5,
#      'AverageSpeed': 123.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
# ...
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Wide': {'AdCourt': {'FirstServesAttempted': 23,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 23,
#     'TotalServesMade': 21,
#     'Summary': {'ServesAttempted': 12,
#      'ServesMade': 12,
#      'ServesWon': 11,
#      'ServesMadePercentage': '57.1%',
#      'ServesWonPercentage': '91.7%',
#      'Aces': 5,
#      'Unreturned': 2,
#      'Returned': 5,
#      'AverageSpeed': 125.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 5,
#      'ServesMade': 5,
#      'ServesWon': 5,
#      'ServesMadePercentage': '41.7%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 3,
#      'Unreturned': 1,
#      'Returned': 1,
#      'AverageSpeed': 126.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 5,
#      'ServesMade': 5,
#      'ServesWon': 4,
#      'ServesMadePercentage': '41.7%',
#      'ServesWonPercentage': '80.0%',
#      'Aces': 1,
#      'Unreturned': 0,
#      'Returned': 4,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '16.7%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 1,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'CacheTags': None},
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  {'T': {'AdCourt': {'FirstServesAttempted': 16,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 16,
#     'TotalServesMade': 14,
#     'Summary': {'ServesAttempted': 5,
#      'ServesMade': 4,
#      'ServesWon': 4,
#      'ServesMadePercentage': '28.6%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 3,
#      'Returned': 1,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 5,
#      'ServesMade': 4,
#      'ServesWon': 4,
#      'ServesMadePercentage': '100.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 3,
#      'Returned': 1,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Mid': {'AdCourt': {'FirstServesAttempted': 16,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 16,
#     'TotalServesMade': 14,
#     'Summary': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '14.3%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 1,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '50.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '50.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 0,
#      'AverageSpeed': 120.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Wide': {'AdCourt': {'FirstServesAttempted': 16,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 16,
#     'TotalServesMade': 14,
#     'Summary': {'ServesAttempted': 9,
#      'ServesMade': 8,
#      'ServesWon': 3,
#      'ServesMadePercentage': '57.1%',
#      'ServesWonPercentage': '37.5%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 7,
#      'AverageSpeed': 114.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '12.5%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 92.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 0,
#      'ServesMadePercentage': '12.5%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 87.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '25.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 1,
#      'AverageSpeed': 123.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 4,
#      'ServesMade': 3,
#      'ServesWon': 0,
#      'ServesMadePercentage': '37.5%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 3,
#      'AverageSpeed': 121.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 0,
#      'ServesMadePercentage': '12.5%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'CacheTags': None},
#  'None',
#  'None',
#  'None',
#  'None',
#  {'T': {'AdCourt': {'FirstServesAttempted': 31,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 31,
#     'TotalServesMade': 31,
#     'Summary': {'ServesAttempted': 11,
#      'ServesMade': 11,
#      'ServesWon': 9,
#      'ServesMadePercentage': '35.5%',
#      'ServesWonPercentage': '81.8%',
#      'Aces': 5,
#      'Unreturned': 0,
#      'Returned': 6,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '9.1%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 116.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 0,
#      'ServesMadePercentage': '9.1%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 123.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 2,
#      'ServesMadePercentage': '18.2%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 2,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 0,
#      'ServesMadePercentage': '9.1%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 125.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 6,
#      'ServesMade': 6,
#      'ServesWon': 6,
#      'ServesMadePercentage': '54.5%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 5,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 122.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Mid': {'AdCourt': {'FirstServesAttempted': 31,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 31,
#     'TotalServesMade': 31,
#     'Summary': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 0,
#      'ServesMade': 0,
#      'ServesWon': 0,
#      'ServesMadePercentage': '0.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 0,
#      'AverageSpeed': 0.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'Wide': {'AdCourt': {'FirstServesAttempted': 31,
#     'SecondServesAttempted': 0,
#     'TotalServesAttempted': 31,
#     'TotalServesMade': 31,
#     'Summary': {'ServesAttempted': 20,
#      'ServesMade': 20,
#      'ServesWon': 12,
#      'ServesMadePercentage': '64.5%',
#      'ServesWonPercentage': '60.0%',
#      'Aces': 0,
#      'Unreturned': 3,
#      'Returned': 17,
#      'AverageSpeed': 113.0,
#      'AverageSpin': 0},
#     'MiddleLeft': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '5.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 98.0,
#      'AverageSpin': 0},
#     'MiddleCenter': {'ServesAttempted': 4,
#      'ServesMade': 4,
#      'ServesWon': 1,
#      'ServesMadePercentage': '20.0%',
#      'ServesWonPercentage': '25.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 4,
#      'AverageSpeed': 94.0,
#      'AverageSpin': 0},
#     'MiddleRight': {'ServesAttempted': 1,
#      'ServesMade': 1,
#      'ServesWon': 1,
#      'ServesMadePercentage': '5.0%',
#      'ServesWonPercentage': '100.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 1,
#      'AverageSpeed': 118.0,
#      'AverageSpin': 0},
#     'DeepLeft': {'ServesAttempted': 4,
#      'ServesMade': 4,
#      'ServesWon': 3,
#      'ServesMadePercentage': '20.0%',
#      'ServesWonPercentage': '75.0%',
#      'Aces': 0,
#      'Unreturned': 2,
#      'Returned': 2,
#      'AverageSpeed': 103.0,
#      'AverageSpin': 0},
#     'DeepCenter': {'ServesAttempted': 8,
#      'ServesMade': 8,
#      'ServesWon': 6,
#      'ServesMadePercentage': '40.0%',
#      'ServesWonPercentage': '75.0%',
#      'Aces': 0,
#      'Unreturned': 1,
#      'Returned': 7,
#      'AverageSpeed': 124.0,
#      'AverageSpin': 0},
#     'DeepRight': {'ServesAttempted': 2,
#      'ServesMade': 2,
#      'ServesWon': 0,
#      'ServesMadePercentage': '10.0%',
#      'ServesWonPercentage': '0.0%',
#      'Aces': 0,
#      'Unreturned': 0,
#      'Returned': 2,
#      'AverageSpeed': 126.0,
#      'AverageSpin': 0}},
#    'DeuceCourt': None},
#   'CacheTags': None}]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [180], in <cell line: 1>()
# ----> 1 pd.DataFrame(filtered_ad_lst[0],filtered_ad_lst[0])
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:756, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     753 # For data is scalar
#     754 else:
#     755     if index is None or columns is None:
# --> 756         raise ValueError("DataFrame constructor not properly called!")
#     758     # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#     759     # expected "Union[Union[Union[ExtensionArray, ndarray],
#     760     # Index, Series], Sequence[Any]]"
#     761     index = ensure_index(index)  # type: ignore[arg-type]
#
# ValueError: DataFrame constructor not properly called!

# %%
t_ad_lst=[]
mid_ad_lst=[]
wide_ad_lst=[]
for i in range(100):
    t_ad_lst.append(player_ad_lst[i]["T"])
    mid_ad_lst.append(player_ad_lst[i]["Mid"])
    widead_lst.append(player_ad_lst[i]["Wide"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [161], in <cell line: 4>()
#       3 wide_ad_lst=[]
#       4 for i in range(100):
# ----> 5     t_ad_lst.append(player_ad_lst[i]["T"])
#       6     mid_ad_lst.append(player_ad_lst[i]["Mid"])
#       7     widead_lst.append(player_ad_lst[i]["Wide"])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Out:
# {'AdCourt': None,
#  'DeuceCourt': {'FirstServesAttempted': 30,
#   'SecondServesAttempted': 0,
#   'TotalServesAttempted': 30,
#   'TotalServesMade': 29,
#   'Summary': {'ServesAttempted': 11,
#    'ServesMade': 11,
#    'ServesWon': 9,
#    'ServesMadePercentage': '37.9%',
#    'ServesWonPercentage': '81.8%',
#    'Aces': 3,
#    'Unreturned': 2,
#    'Returned': 6,
#    'AverageSpeed': 124.0,
#    'AverageSpin': 0},
#   'MiddleLeft': {'ServesAttempted': 2,
#    'ServesMade': 2,
#    'ServesWon': 1,
#    'ServesMadePercentage': '18.2%',
#    'ServesWonPercentage': '50.0%',
#    'Aces': 0,
#    'Unreturned': 0,
#    'Returned': 2,
#    'AverageSpeed': 125.0,
#    'AverageSpin': 0},
#   'MiddleCenter': {'ServesAttempted': 0,
#    'ServesMade': 0,
#    'ServesWon': 0,
#    'ServesMadePercentage': '0.0%',
#    'ServesWonPercentage': '0.0%',
#    'Aces': 0,
#    'Unreturned': 0,
#    'Returned': 0,
#    'AverageSpeed': 0.0,
#    'AverageSpin': 0},
#   'MiddleRight': {'ServesAttempted': 0,
#    'ServesMade': 0,
#    'ServesWon': 0,
#    'ServesMadePercentage': '0.0%',
#    'ServesWonPercentage': '0.0%',
#    'Aces': 0,
#    'Unreturned': 0,
#    'Returned': 0,
#    'AverageSpeed': 0.0,
#    'AverageSpin': 0},
#   'DeepLeft': {'ServesAttempted': 8,
#    'ServesMade': 8,
#    'ServesWon': 7,
#    'ServesMadePercentage': '72.7%',
#    'ServesWonPercentage': '87.5%',
#    'Aces': 3,
#    'Unreturned': 2,
#    'Returned': 3,
#    'AverageSpeed': 123.0,
#    'AverageSpin': 0},
#   'DeepCenter': {'ServesAttempted': 1,
#    'ServesMade': 1,
#    'ServesWon': 1,
#    'ServesMadePercentage': '9.1%',
#    'ServesWonPercentage': '100.0%',
#    'Aces': 0,
#    'Unreturned': 0,
#    'Returned': 1,
#    'AverageSpeed': 126.0,
#    'AverageSpin': 0},
#   'DeepRight': {'ServesAttempted': 0,
#    'ServesMade': 0,
#    'ServesWon': 0,
#    'ServesMadePercentage': '0.0%',
#    'ServesWonPercentage': '0.0%',
#    'Aces': 0,
#    'Unreturned': 0,
#    'Returned': 0,
#    'AverageSpeed': 0.0,
#    'AverageSpin': 0}}}

# %%
t_summary_keys = t["DeuceCourt"]["Summary"].keys()

# %%
t_summary_keys
# Out:
# dict_keys(['ServesAttempted', 'ServesMade', 'ServesWon', 'ServesMadePercentage', 'ServesWonPercentage', 'Aces', 'Unreturned', 'Returned', 'AverageSpeed', 'AverageSpin'])

# %%
t["DeuceCourt"]["Summary"]
# Out:
# {'ServesAttempted': 11,
#  'ServesMade': 11,
#  'ServesWon': 9,
#  'ServesMadePercentage': '37.9%',
#  'ServesWonPercentage': '81.8%',
#  'Aces': 3,
#  'Unreturned': 2,
#  'Returned': 6,
#  'AverageSpeed': 124.0,
#  'AverageSpin': 0}

# %%
for key in t_summary_keys:
    print(t["DeuceCourt"]["Summary"][key])
# Out:
# 11
# 11
# 9
# 37.9%
# 81.8%
# 3
# 2
# 6
# 124.0
# 0

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
new = pd.DataFrame({"example": [45,56,67]})

# %%
for key in t_summary_keys:
    df[key] = [t["DeuceCourt"]["Summary"][key]]

# %%
df
# Out:
#    ServesAttempted  ServesMade  ServesWon ServesMadePercentage  \
# 0               11          11          9                37.9%
#
#   ServesWonPercentage  Aces  Unreturned  Returned  AverageSpeed  AverageSpin
# 0               81.8%     3           2         6         124.0            0
