# %%
import numpy as np
import pandas as pd
import os

# %%
data = pd.read_csv('/home/gibbons/code/TomislavMatus/Nole/data/q_and_a.csv')

# %%
data.drop(columns= ['Unnamed: 0'], inplace=True)

# %%
row = data.iloc[1]
pd.DataFrame(row.T)
# Out:
#                                                                       1
# Date                                                         2022-07-08
# Transcript            \nTHE CHAMPIONSHIPS\n\nJuly 8, 2022\n\nNovak D...
# Competition                                           THE CHAMPIONSHIPS
# Shortened_Transcript  Q. It seemed like you were blowing kisses at a...

# %%
def last_match(value, df):
    if

# %%
data['last_match'] =
# Out:
#                                                     Unnamed: 0  Date  \
# Competition
# AEGON INTERNATIONAL                                          5     5
# ATP CUP                                                     10    10
# AUSTRALIAN OPEN                                            105   105
# BARCLAYS ATP WORLD TOUR FINALS                              35    35
# BARCLAYS DUBAI TENNIS CHAMPIONSHIPS                          4     4
# BARCLAYS DUBAI TENNIS CHAMPIONSHIPS MEN                      5     5
# BNP PARIBAS MASTERS                                         15    15
# BNP PARIBAS MASTERS PARIS                                    4     4
# BNP PARIBAS OPEN                                            50    50
# CHINA OPEN                                                  28    28
# COUPE ROGERS                                                 9     9
# DAVIS CUP BY BNP PARIBAS WORLD GROUP FINAL: FRA...           6     6
# ...
